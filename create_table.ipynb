# %%
import sqlite3

# SQLite 데이터베이스 파일에 연결 (없으면 생성됨)
conn = sqlite3.connect('test_database.db')
cursor = conn.cursor()

# 테이블 생성 (캠페인 게시판 예시)
cursor.execute('''
    CREATE TABLE IF NOT EXISTS campaign_board (
        campaign_id INTEGER PRIMARY KEY AUTOINCREMENT,
        title TEXT NOT NULL,
        description TEXT,
        created_by TEXT NOT NULL,
        start_date DATE,
        end_date DATE,
        total_funds REAL DEFAULT 0,
        view_count INTEGER DEFAULT 0,
        created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP,
        updated_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
''')

# 변경사항 저장
conn.commit()

# 연결 종료
conn.close()

# %%
import sqlite3

# SQLite 데이터베이스 파일에 연결
conn = sqlite3.connect('test_database.db')
cursor = conn.cursor()

# 데이터 리스트 (30건의 데이터)
data = [
    ('환경 보호 캠페인 1', '지구를 위한 환경 보호 활동 1', 'admin', '2024-01-01', '2024-12-31', 100000, 120),
    ('환경 보호 캠페인 2', '지구를 위한 환경 보호 활동 2', 'admin', '2024-02-01', '2024-12-31', 120000, 110),
    ('환경 보호 캠페인 3', '지구를 위한 환경 보호 활동 3', 'user1', '2024-03-01', '2024-12-31', 130000, 90),
    ('환경 보호 캠페인 4', '지구를 위한 환경 보호 활동 4', 'user2', '2024-04-01', '2024-12-31', 80000, 80),
    ('환경 보호 캠페인 5', '지구를 위한 환경 보호 활동 5', 'user3', '2024-05-01', '2024-12-31', 150000, 140),
    ('환경 보호 캠페인 6', '지구를 위한 환경 보호 활동 6', 'user4', '2024-06-01', '2024-12-31', 90000, 70),
    ('환경 보호 캠페인 7', '지구를 위한 환경 보호 활동 7', 'user5', '2024-07-01', '2024-12-31', 110000, 100),
    ('환경 보호 캠페인 8', '지구를 위한 환경 보호 활동 8', 'user6', '2024-08-01', '2024-12-31', 115000, 90),
    ('환경 보호 캠페인 9', '지구를 위한 환경 보호 활동 9', 'user7', '2024-09-01', '2024-12-31', 95000, 60),
    ('환경 보호 캠페인 10', '지구를 위한 환경 보호 활동 10', 'user8', '2024-10-01', '2024-12-31', 100000, 80),
    ('환경 보호 캠페인 11', '지구를 위한 환경 보호 활동 11', 'user9', '2024-11-01', '2024-12-31', 200000, 150),
    ('환경 보호 캠페인 12', '지구를 위한 환경 보호 활동 12', 'user10', '2024-12-01', '2024-12-31', 75000, 70),
    ('환경 보호 캠페인 13', '지구를 위한 환경 보호 활동 13', 'admin', '2024-01-01', '2024-12-31', 105000, 130),
    ('환경 보호 캠페인 14', '지구를 위한 환경 보호 활동 14', 'admin', '2024-02-01', '2024-12-31', 80000, 90),
    ('환경 보호 캠페인 15', '지구를 위한 환경 보호 활동 15', 'admin', '2024-03-01', '2024-12-31', 90000, 85),
    ('환경 보호 캠페인 16', '지구를 위한 환경 보호 활동 16', 'admin', '2024-04-01', '2024-12-31', 95000, 75),
    ('환경 보호 캠페인 17', '지구를 위한 환경 보호 활동 17', 'admin', '2024-05-01', '2024-12-31', 110000, 95),
    ('환경 보호 캠페인 18', '지구를 위한 환경 보호 활동 18', 'admin', '2024-06-01', '2024-12-31', 120000, 140),
    ('환경 보호 캠페인 19', '지구를 위한 환경 보호 활동 19', 'user1', '2024-07-01', '2024-12-31', 130000, 115),
    ('환경 보호 캠페인 20', '지구를 위한 환경 보호 활동 20', 'user2', '2024-08-01', '2024-12-31', 95000, 85),
    ('환경 보호 캠페인 21', '지구를 위한 환경 보호 활동 21', 'user3', '2024-09-01', '2024-12-31', 145000, 135),
    ('환경 보호 캠페인 22', '지구를 위한 환경 보호 활동 22', 'user4', '2024-10-01', '2024-12-31', 155000, 170),
    ('환경 보호 캠페인 23', '지구를 위한 환경 보호 활동 23', 'user5', '2024-11-01', '2024-12-31', 160000, 150),
    ('환경 보호 캠페인 24', '지구를 위한 환경 보호 활동 24', 'user6', '2024-12-01', '2024-12-31', 170000, 190),
    ('환경 보호 캠페인 25', '지구를 위한 환경 보호 활동 25', 'user7', '2024-01-01', '2024-12-31', 180000, 200),
    ('환경 보호 캠페인 26', '지구를 위한 환경 보호 활동 26', 'user8', '2024-02-01', '2024-12-31', 135000, 140),
    ('환경 보호 캠페인 27', '지구를 위한 환경 보호 활동 27', 'user9', '2024-03-01', '2024-12-31', 125000, 130),
    ('환경 보호 캠페인 28', '지구를 위한 환경 보호 활동 28', 'user10', '2024-04-01', '2024-12-31', 115000, 110),
    ('환경 보호 캠페인 29', '지구를 위한 환경 보호 활동 29', 'admin', '2024-05-01', '2024-12-31', 140000, 125),
    ('환경 보호 캠페인 30', '지구를 위한 환경 보호 활동 30', 'admin', '2024-06-01', '2024-12-31', 150000, 135)
]

# 여러 행의 데이터를 삽입할 때 executemany 사용
cursor.executemany('''
    INSERT INTO campaign_board (title, description, created_by, start_date, end_date, total_funds, view_count)
    VALUES (?, ?, ?, ?, ?, ?, ?)
''', data)

# 변경사항 저장
conn.commit()

# 데이터 조회
cursor.execute('SELECT * FROM campaign_board')
rows = cursor.fetchall()

for row in rows:
    print(row)

# 연결 종료
conn.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 cursor = conn.cursor()
#       7 # 데이터 삽입
# ----> 8 cursor.execute('''
#       9     INSERT INTO campaign_board (title, description, created_by, start_date, end_date, total_funds, view_count)
#      10     VALUES (?, ?, ?, ?, ?, ?, ?)
#      11 ''',
#      12 ('환경 보호 캠페인 1', '지구를 위한 환경 보호 활동 1', 'admin', '2024-01-01', '2024-12-31', 100000, 120),
#      13 ('환경 보호 캠페인 2', '지구를 위한 환경 보호 활동 2', 'admin', '2024-02-01', '2024-12-31', 120000, 110),
#      14 ('환경 보호 캠페인 3', '지구를 위한 환경 보호 활동 3', 'user1', '2024-03-01', '2024-12-31', 130000, 90),
#      15 ('환경 보호 캠페인 4', '지구를 위한 환경 보호 활동 4', 'user2', '2024-04-01', '2024-12-31', 80000, 80),
#      16 ('환경 보호 캠페인 5', '지구를 위한 환경 보호 활동 5', 'user3', '2024-05-01', '2024-12-31', 150000, 140),
# ...
